# %% [markdown]
# ## Estimación del modelo

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('base_final.csv')

# %%
year = pd.Categorical(df["ao"])

# %%
data = df.set_index(["edo","ao"])

# %%
data['ao'] = year

# %%
print(data.head())
# Out:
#                      clave_ent  homicidio  robocasa  robocalle  robocarro  \
# edo            ao
# Aguascalientes 2015          1        211      2525       1754       1995
#                2016          1        233      2459       1353       3110
#                2017          1        258      3327       1949       3624
#                2018          1        283      3355       2216       3309
#                2019          1        269      2817       1780       2399
#
#                      extorsion  tasa_hom  tasa_rcasa  tasa_rcalle  \
# edo            ao
# Aguascalientes 2015         39     15.84      189.59       131.70
#                2016         70     17.19      181.43        99.83
#                2017        121     18.75      241.83       141.66
#                2018        138     20.28      240.36       158.76
#                2019        116     19.00      199.02       125.76
#
#                      tasa_rcarro  ...  edad15a24  edad25a34  edad35a44  \
# edo            ao                 ...
# Aguascalientes 2015       149.79  ...     255649     211782     175356
#                2016       229.47  ...     258733     217183     178187
#                2017       263.41  ...     260495     222453     180840
#                2018       237.07  ...     261963     227600     183553
#                2019       169.49  ...     263225     232527     186443
#
#                      edad45mas  pob_tot         pibe   ingreso  pob_ext  \
# edo            ao
# Aguascalientes 2015     296621  1331825  198220.6406  207024.0     2.09
#                2016     308198  1355321  211672.4688  203879.0     2.30
#                2017     320035  1375782  216705.5625  206760.0     2.18
#                2018     331996  1395794  224807.4688  222261.0     1.17
#                2019     344052  1415421  223622.4844       NaN      NaN
#
#                      pobreza    ao
# edo            ao
# Aguascalientes 2015    31.58  2015
#                2016    28.22  2016
#                2017    25.99  2017
#                2018    26.18  2018
#                2019      NaN  2019
#
# [5 rows x 22 columns]

# %%
data["logpibe"] = np.log(data["pibe"])
data["prop25a34"] = data["edad25a34"]*100/data["pob_tot"]

# %%
import linearmodels as linearmodels
from linearmodels.panel import PooledOLS
import statsmodels.api as sm

# %%
exog_vars = ['prop25a34','desocupa','logpibe','pobreza']
exog = sm.add_constant(data[exog_vars])
mod = PooledOLS(data.tasa_rcasa, exog)
pooled_res = mod.fit()
print(pooled_res)
# Out:
#                           PooledOLS Estimation Summary
# ================================================================================
# Dep. Variable:             tasa_rcasa   R-squared:                        0.5040
# Estimator:                  PooledOLS   R-squared (Between):              0.5469
# No. Observations:                 128   R-squared (Within):              -0.0335
# Date:                Sun, Jul 19 2020   R-squared (Overall):              0.5040
# Time:                        22:36:34   Log-likelihood                   -712.74
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      31.251
# Entities:                          32   P-value                           0.0000
# Avg Obs:                       4.0000   Distribution:                   F(4,123)
# Min Obs:                       4.0000
# Max Obs:                       4.0000   F-statistic (robust):             31.251
#                                         P-value                           0.0000
# Time periods:                       4   Distribution:                   F(4,123)
# Avg Obs:                       32.000
# Min Obs:                       32.000
# Max Obs:                       32.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          121.34     177.35     0.6842     0.4951     -229.70      472.39
# prop25a34      40.646     8.5665     4.7447     0.0000      23.689      57.602
# desocupa       5.2567     5.4841     0.9585     0.3397     -5.5986      16.112
# logpibe       -46.449     7.5371    -6.1628     0.0000     -61.368     -31.530
# pobreza       -2.3939     0.4552    -5.2594     0.0000     -3.2949     -1.4930
# ==============================================================================
# /srv/conda/envs/notebook/lib/python3.7/site-packages/numpy/core/fromnumeric.py:42: RuntimeWarning: invalid value encountered in reduce
#   result = getattr(asarray(obj), method)(*args, **kwds)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/linearmodels/utility.py:549: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)

# %%
from linearmodels.panel import RandomEffects
mod = RandomEffects(data.tasa_rcasa, exog)
re_res = mod.fit()
print(re_res)
# Out:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:             tasa_rcasa   R-squared:                        0.2133
# Estimator:              RandomEffects   R-squared (Between):              0.5319
# No. Observations:                 128   R-squared (Within):               0.0108
# Date:                Sun, Jul 19 2020   R-squared (Overall):              0.4935
# Time:                        22:41:49   Log-likelihood                   -606.99
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      8.3355
# Entities:                          32   P-value                           0.0000
# Avg Obs:                       4.0000   Distribution:                   F(4,123)
# Min Obs:                       4.0000
# Max Obs:                       4.0000   F-statistic (robust):             8.3355
#                                         P-value                           0.0000
# Time periods:                       4   Distribution:                   F(4,123)
# Avg Obs:                       32.000
# Min Obs:                       32.000
# Max Obs:                       32.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          148.36     317.96     0.4666     0.6416     -481.02      777.74
# prop25a34      37.524     14.897     2.5189     0.0131      8.0358      67.012
# desocupa       12.535     4.9941     2.5100     0.0134      2.6496      22.421
# logpibe       -48.080     14.214    -3.3825     0.0010     -76.216     -19.944
# pobreza       -1.9734     0.7498    -2.6319     0.0096     -3.4575     -0.4892
# ==============================================================================
